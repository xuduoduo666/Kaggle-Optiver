# %% [markdown]
# # Version 1: Feature Selection

# %% [markdown]
# ## 1 Download Data

# %% [markdown]
# ## 2 Feature Selection

# %%
import gc
import os
import time
import warnings
from itertools import combinations
from warnings import simplefilter

import joblib
import lightgbm as lgb
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold, TimeSeriesSplit
import polars as pl
from sklearn.preprocessing import MinMaxScaler
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
warnings.filterwarnings("ignore")
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

import seaborn as sns
import matplotlib.pyplot as plt
from catboost import CatBoostRegressor, EShapCalcType, EFeaturesSelectionAlgorithm
from sklearn.metrics import mean_absolute_error

is_offline = True
is_train = True
is_infer = True
max_lookback = np.nan
split_day = 435 #The testing data constixtute 90% = 435 / 481
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 11.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(

# %%
df = pd.read_csv("/kaggle/input/optiver-trading-at-the-close/optiver-trading-at-the-close/train.csv")
df = df.dropna(subset=["target"])
df.reset_index(drop=True, inplace=True)
df.shape
# Out:
# (5237892, 17)

# %%
#To reduce memory usage
def reduce_mem_usage(df, verbose=0):
    """
    Iterate through all numeric columns of a dataframe and modify the data type
    to reduce memory usage.
    """

    start_mem = df.memory_usage().sum() / 1024**2

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float32)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float32)

    if verbose:
        logger.info(f"Memory usage of dataframe is {start_mem:.2f} MB")
        end_mem = df.memory_usage().sum() / 1024**2
        logger.info(f"Memory usage after optimization is: {end_mem:.2f} MB")
        decrease = 100 * (start_mem - end_mem) / start_mem
        logger.info(f"Decreased by {decrease:.2f}%")

    return df

# %% [markdown]
# ### 2.1 Imbalance Features

# %%
# Import Numba for just-in-time (JIT) compilation and parallel processing
from numba import njit, prange

# Function to compute triplet imbalance in parallel using Numba
@njit(parallel=True)
def compute_triplet_imbalance(df_values, comb_indices):
    num_rows = df_values.shape[0]
    num_combinations = len(comb_indices)
    imbalance_features = np.empty((num_rows, num_combinations))

    # Loop through all combinations of triplets
    for i in prange(num_combinations):
        a, b, c = comb_indices[i]

        # Loop through rows of the DataFrame
        for j in range(num_rows):
            max_val = max(df_values[j, a], df_values[j, b], df_values[j, c])
            min_val = min(df_values[j, a], df_values[j, b], df_values[j, c])
            mid_val = df_values[j, a] + df_values[j, b] + df_values[j, c] - min_val - max_val

            # Prevent division by zero
            if mid_val == min_val:
                imbalance_features[j, i] = np.nan
            else:
                imbalance_features[j, i] = (max_val - mid_val) / (mid_val - min_val)

    return imbalance_features

# Function to calculate triplet imbalance for given price data and a DataFrame
def calculate_triplet_imbalance_numba(price, df):
    # Convert DataFrame to numpy array for Numba compatibility
    df_values = df[price].values
    comb_indices = [(price.index(a), price.index(b), price.index(c)) for a, b, c in combinations(price, 3)]

    # Calculate the triplet imbalance using the Numba-optimized function
    features_array = compute_triplet_imbalance(df_values, comb_indices)

    # Create a DataFrame from the results
    columns = [f"{a}_{b}_{c}_imb2" for a, b, c in combinations(price, 3)]
    features = pd.DataFrame(features_array, columns=columns)

    return features

# %%
# generate imbalance features
def imbalance_features(df):
    prices = ["reference_price", "far_price", "near_price", "ask_price", "bid_price", "wap"]
    sizes = ["matched_size", "bid_size", "ask_size", "imbalance_size"]

    # V1
    df["volume"] = df.eval("ask_size + bid_size")
    df["mid_price"] = df.eval("(ask_price + bid_price) / 2")
    df["liquidity_imbalance"] = df.eval("(bid_size-ask_size)/(bid_size+ask_size)")
    df["matched_imbalance"] = df.eval("(imbalance_size-matched_size)/(matched_size+imbalance_size)")
    df["size_imbalance"] = df.eval("bid_size / ask_size")
    # Create features for pairwise price imbalances
    for c in combinations(prices, 2):
        df[f"{c[0]}_{c[1]}_imb"] = df.eval(f"({c[0]} - {c[1]})/({c[0]} + {c[1]})")
    # Calculate triplet imbalance features using the Numba-optimized function
    for c in [['ask_price', 'bid_price', 'wap', 'reference_price'], sizes]:
        triplet_feature = calculate_triplet_imbalance_numba(c, df)
        df[triplet_feature.columns] = triplet_feature.values


    # V2
    df["stock_weights"] = df["stock_id"].map(weights)
    df["weighted_wap"] = df["stock_weights"] * df["wap"]
    df['wap_momentum'] = df.groupby('stock_id')['weighted_wap'].pct_change(periods=6)
    df["imbalance_momentum"] = df.groupby(['stock_id'])['imbalance_size'].diff(periods=1) / df['matched_size']
    df["price_spread"] = df["ask_price"] - df["bid_price"]
    df["spread_intensity"] = df.groupby(['stock_id'])['price_spread'].diff()
    df['price_pressure'] = df['imbalance_size'] * (df['ask_price'] - df['bid_price'])
    df['market_urgency'] = df['price_spread'] * df['liquidity_imbalance']
    df['depth_pressure'] = (df['ask_size'] - df['bid_size']) * (df['far_price'] - df['near_price'])
    df['spread_depth_ratio'] = (df['ask_price'] - df['bid_price']) / (df['bid_size'] + df['ask_size'])
    df['mid_price_movement'] = df['mid_price'].diff(periods=5).apply(lambda x: 1 if x > 0 else (-1 if x < 0 else 0))
    df['micro_price'] = ((df['bid_price'] * df['ask_size']) + (df['ask_price'] * df['bid_size'])) / (df['bid_size'] + df['ask_size'])
    df['relative_spread'] = (df['ask_price'] - df['bid_price']) / df['wap']

    #价量横截面统计特征（均值，标准差，偏度，峰度）
    for func in ["mean", "std", "skew", "kurt"]:
        df[f"all_prices_{func}"] = df[prices].agg(func, axis=1)
        df[f"all_sizes_{func}"] = df[sizes].agg(func, axis=1)


    # V3
    # Calculate shifted and return features for specific columns
    for col in ['matched_size', 'imbalance_size', 'reference_price', 'imbalance_buy_sell_flag']:
        for window in [1, 2, 3, 5, 10]:
            df[f"{col}_shift_{window}"] = df.groupby('stock_id')[col].shift(window)
            df[f"{col}_ret_{window}"] = df.groupby('stock_id')[col].pct_change(window)


    # Calculate diff features for specific columns
    for col in ['ask_price', 'bid_price', 'ask_size', 'bid_size',
                'wap', 'near_price', 'far_price']:#'weighted_wap','price_spread'
        for window in [1, 2, 3, 5, 10]:
            df[f"{col}_diff_{window}"] = df.groupby("stock_id")[col].diff(window)

    #V4
    for window in [3, 5, 10]:
        df[f'price_change_diff_{window}'] = df[f'bid_price_diff_{window}'] - df[f'ask_price_diff_{window}']
        df[f'size_change_diff_{window}'] = df[f'bid_size_diff_{window}'] - df[f'ask_size_diff_{window}']

    #V5
    pl_df = pl.from_pandas(df)

    windows = [3, 5, 10]
    columns = ['ask_price', 'bid_price', 'ask_size', 'bid_size']

    group = ["stock_id"]
    expressions = []

    for window in windows:
        for col in columns:
            rolling_mean_expr = (
                pl.col(f"{col}_diff_{window}")
                .rolling_mean(window)
                .over(group)
                .alias(f'rolling_diff_{col}_{window}')
            )

            rolling_std_expr = (
                pl.col(f"{col}_diff_{window}")
                .rolling_std(window)
                .over(group)
                .alias(f'rolling_std_diff_{col}_{window}')
            )

            expressions.append(rolling_mean_expr)
            expressions.append(rolling_std_expr)

    lazy_df = pl_df.lazy().with_columns(expressions)

    pl_df = lazy_df.collect()

    df = pl_df.to_pandas()
    gc.collect()

    df['mid_price*volume'] = df['mid_price_movement'] * df['volume']
    df['harmonic_imbalance'] = df.eval('2 / ((1 / bid_size) + (1 / ask_size))')

    for col in df.columns:
        df[col] = df[col].replace([np.inf, -np.inf], 0)

    return df

# generate time & stock features
def other_features(df):
    df["dow"] = df["date_id"] % 5
    df["dom"] = df["date_id"] % 20
    df["seconds"] = df["seconds_in_bucket"] % 60
    df["minute"] = df["seconds_in_bucket"] // 60

    for key, value in global_stock_id_feats.items():
        df[f"global_{key}"] = df["stock_id"].map(value.to_dict())

    return df

# %%
#Stock weights for calculating imbalnce features
weights = [
    0.004, 0.001, 0.002, 0.006, 0.004, 0.004, 0.002, 0.006, 0.006, 0.002, 0.002, 0.008,
    0.006, 0.002, 0.008, 0.006, 0.002, 0.006, 0.004, 0.002, 0.004, 0.001, 0.006, 0.004,
    0.002, 0.002, 0.004, 0.002, 0.004, 0.004, 0.001, 0.001, 0.002, 0.002, 0.006, 0.004,
    0.004, 0.004, 0.006, 0.002, 0.002, 0.04 , 0.002, 0.002, 0.004, 0.04 , 0.002, 0.001,
    0.006, 0.004, 0.004, 0.006, 0.001, 0.004, 0.004, 0.002, 0.006, 0.004, 0.006, 0.004,
    0.006, 0.004, 0.002, 0.001, 0.002, 0.004, 0.002, 0.008, 0.004, 0.004, 0.002, 0.004,
    0.006, 0.002, 0.004, 0.004, 0.002, 0.004, 0.004, 0.004, 0.001, 0.002, 0.002, 0.008,
    0.02 , 0.004, 0.006, 0.002, 0.02 , 0.002, 0.002, 0.006, 0.004, 0.002, 0.001, 0.02,
    0.006, 0.001, 0.002, 0.004, 0.001, 0.002, 0.006, 0.006, 0.004, 0.006, 0.001, 0.002,
    0.004, 0.006, 0.006, 0.001, 0.04 , 0.006, 0.002, 0.004, 0.002, 0.002, 0.006, 0.002,
    0.002, 0.004, 0.006, 0.006, 0.002, 0.002, 0.008, 0.006, 0.004, 0.002, 0.006, 0.002,
    0.004, 0.006, 0.002, 0.004, 0.001, 0.004, 0.002, 0.004, 0.008, 0.006, 0.008, 0.002,
    0.004, 0.002, 0.001, 0.004, 0.004, 0.004, 0.006, 0.008, 0.004, 0.001, 0.001, 0.002,
    0.006, 0.004, 0.001, 0.002, 0.006, 0.004, 0.006, 0.008, 0.002, 0.002, 0.004, 0.002,
    0.04 , 0.002, 0.002, 0.004, 0.002, 0.002, 0.006, 0.02 , 0.004, 0.002, 0.006, 0.02,
    0.001, 0.002, 0.006, 0.004, 0.006, 0.004, 0.004, 0.004, 0.004, 0.002, 0.004, 0.04,
    0.002, 0.008, 0.002, 0.004, 0.001, 0.004, 0.006, 0.004,
]

weights = {int(k):v for k,v in enumerate(weights)}

# %% [markdown]
# ### 2.2 Stock Classification Features

# %% [markdown]
# We first calculate ***correlation matrix*** of WAP, based on which we assign clusters to stocks. 1）After normalize the clusters, ranging from （-1, 1）, we try to construct ***stock classification features***. 2）We try to apply Stratifies K-Fold Cross Validation, so to speak carrying out CV by groups to train model ( LightGBM ) and fature selection ( REF ).

# %%
#Correlation Matrix of WAP
def calculate_daily_returns(stock_data):
    stock_data['return'] = stock_data['wap'].pct_change()
    return stock_data[['return', 'seconds_in_bucket']].dropna()  # Keep 'return' and 'seconds_in_bucket' columns

returns = df.groupby(['stock_id', 'date_id']).apply(calculate_daily_returns).reset_index()

# 2. Align the data for each stock by filling in the gaps (if any) and then concatenate the returns to form a matrix
# For this step, we will pivot the data so each stock has its own column, and each row represents a timestamp.
pivot_returns = returns.pivot_table(index=['date_id', 'seconds_in_bucket'],
                                    columns='stock_id',
                                    values='return')

# handle missing values by filling the average of all available
pivot_returns = pivot_returns.apply(lambda row: row.fillna(row.mean()), axis=1)

# 3. Compute the correlation matrix for all stocks
correlation_matrix = pivot_returns.corr()
#print(correlation_matrix)

# %%
# Hierarchical clustering
Z = linkage(correlation_matrix, 'ward')
clusters = fcluster(Z, 10, criterion = 'maxclust')

#Assign clusters to stocks
stock_clusters = pd.DataFrame({'stock_id': correlation_matrix.index, 'cluster': clusters})
print(stock_clusters)
# Out:
#      stock_id  cluster
# 0           0        4
# 1           1        7
# 2           2        7
# 3           3        4
# 4           4        4
# ..        ...      ...
# 195       195        5
# 196       196        9
# 197       197        3
# 198       198        5
# 199       199        9
#
# [200 rows x 2 columns]

# %%
#Normalized stock cluster feature

def cluster_feature(df):
    #normalize
    scaler = MinMaxScaler(feature_range=(-1, 1))
    normalized_clusters = scaler.fit_transform(clusters.reshape(-1, 1))

    # Assign clusters to stocks

    # Assign clusters to stocks
    # 1. Extract cluster labels from hierarchical clustering
    df_clusters = pd.DataFrame({'stock_id': pivot_returns.columns, 'cluster_label': normalized_clusters.flatten()})

    # 2. Map cluster labels to each stock ID
    stock_id_to_cluster = dict(zip(df_clusters['stock_id'], df_clusters['cluster_label']))

    # 3. Add cluster labels to your original DataFrame
    df['cluster'] = df['stock_id'].map(stock_id_to_cluster)
    return df

# %% [markdown]
# ### 2.3 PCA_Weighed Average Features * 4

# %% [markdown]
# In this section, we apply PCA on WAG and retrieve the first four elements as features for model training.

# %%
from sklearn.decomposition import PCA

pca = PCA()
principal_components = pca.fit_transform(correlation_matrix)

# %%
#PCA-weighed average price features
def pca_wap_feature(df):

    #Focus on the first 4 components and save as DataFrame

    #Create a pivot table for wap
    price_pivot = df.pivot_table(index=['date_id', 'seconds_in_bucket'], columns='stock_id', values='wap')

    #Generate principal DataFrame
    principal_df = pd.DataFrame(data=principal_components,
                                index=correlation_matrix.index,  # use stock_ids as the index
                                columns=['PC'+str(i) for i in range(1, principal_components.shape[1] + 1)])

    #Ensure the ordering of stock_id in price_pivot and principal_pca is consistent
    ordered_columns = price_pivot.columns
    principal_df = principal_df.loc[ordered_columns].reset_index()

    #Handle NaN values and replace with 0
    price_pivot.fillna(0, inplace=True)
    principal_df.fillna(0, inplace=True)

    #Initialize a dataframe to hold the PCA_WAP values
    pca_wap_df = pd.DataFrame(index=price_pivot.index)

    #Compute 4 WAPs using PCA
    for i in range(1,5):
        pca_wap_df[f'PCA_WAP_{i}'] = (price_pivot.values * principal_df.set_index('stock_id')[f'PC{i}'].values).sum(axis=1)

    #Resetting index for merging purposes
    pca_wap_df = pca_wap_df.reset_index()

    #Merging the PCA_WAP columns with the initial dataset df
    df = df.merge(pca_wap_df, on=['date_id', 'seconds_in_bucket'], how='left')

    return df

# %% [markdown]
# ### 2.4 Feature Generation Function

# %%
# generate all features
def generate_all_features(df):
    cols = [c for c in df.columns if c not in ["row_id", "time_id", "target"]]
    df = df[cols]
    df = imbalance_features(df)
    df = other_features(df)
    df = cluster_feature(df)
    df = pca_wap_feature(df)

    gc.collect()

    feature_name = [i for i in df.columns if i not in ["row_id", "target", "time_id", "date_id"]]

    return df[feature_name]

# %% [markdown]
# ## 3 Feature Generation

# %% [markdown]
# ### 3.1 Dataset Splitting

# %% [markdown]
# When the code is running offline, the entire dataset will be used for training. When the code is running online, 90% data will be used for training and the rest will be used for validation.
# Additionally, for memory saving, after data splitting, we delete the original dataset, so to speak, dataframe, ***df***.

# %%
# Check if the code is running in offline or online mode
if is_offline:
    # In offline mode, split the data into training and validation sets based on the split_day
    df_train = df[df["date_id"] <= split_day]
    df_valid = df[df["date_id"] > split_day]
    print("Offline mode")
    print(f"train : {df_train.shape}, valid : {df_valid.shape}")
else:
    # In online mode, use the entire dataset for training
    df_train = df
    print("Online mode")

del df
gc.collect()
# Out:
# Offline mode
# train : (4742893, 17), valid : (494999, 17)
# 0

# %% [markdown]
# ### 3.2 Feature Generation

# %%
# %%time
if is_train:
    global_stock_id_feats = {
        "median_size": df_train.groupby("stock_id")["bid_size"].median() + df_train.groupby("stock_id")["ask_size"].median(),
        "std_size": df_train.groupby("stock_id")["bid_size"].std() + df_train.groupby("stock_id")["ask_size"].std(),
        "ptp_size": df_train.groupby("stock_id")["bid_size"].max() - df_train.groupby("stock_id")["bid_size"].min(),
        "median_price": df_train.groupby("stock_id")["bid_price"].median() + df_train.groupby("stock_id")["ask_price"].median(),
        "std_price": df_train.groupby("stock_id")["bid_price"].std() + df_train.groupby("stock_id")["ask_price"].std(),
        "ptp_price": df_train.groupby("stock_id")["bid_price"].max() - df_train.groupby("stock_id")["ask_price"].min(),
    }
    if is_offline:
        df_train_feats = generate_all_features(df_train)
        print("Build Train Feats Finished.")
        df_valid_feats = generate_all_features(df_valid)
        print("Build Valid Feats Finished.")
        df_valid_feats = reduce_mem_usage(df_valid_feats)
    else:
        df_train_feats = generate_all_features(df_train)
        print("Build Online Train Feats Finished.")

    df_train_feats = reduce_mem_usage(df_train_feats)

feature_name = list(df_train_feats.columns)
print(f"Feature length = {len(feature_name)}")
# Out:
# Build Train Feats Finished.
# Build Valid Feats Finished.
# Feature length = 184
# CPU times: user 1min 28s, sys: 36 s, total: 2min 5s
# Wall time: 1min 53s

# %% [markdown]
# ## 4 Feature Selection

# %% [markdown]
# ### 4.1 CatBoost for Feature Selection: reducing features from 184 -> 100

# %%
# %%time
# # Train procedure
# if is_train:
#     offline_split = df_train['date_id']>(split_day - 45)
#     df_offline_train = df_train_feats[~offline_split]
#     df_offline_valid = df_train_feats[offline_split]
#     df_offline_train_target = df_train['target'][~offline_split]
#     df_offline_valid_target = df_train['target'][offline_split]
#     df_train_target = df_train["target"]



#     ctb_params = dict(iterations=1200,
#                       learning_rate=1.0,
#                       depth=8,
#                       l2_leaf_reg=30,
#                       bootstrap_type='Bernoulli',
#                       subsample=0.66,
#                       loss_function='MAE',
#                       eval_metric = 'MAE',
#                       metric_period=100,
#                       od_type='Iter',
#                       od_wait=30,
#                       task_type='GPU',
#                       allow_writing_files=False,
#                       )

#     print("Feature Elimination Performing.")
#     ctb_model = CatBoostRegressor(**ctb_params)
#     summary = ctb_model.select_features(
#         df_offline_train[feature_name], df_offline_train_target,
#         eval_set=[(df_offline_valid[feature_name], df_offline_valid_target)],
#         features_for_select=feature_name,
#         num_features_to_select=len(feature_name)-96,    # Dropping from 184 to 100
#         steps=9,
#         algorithm=EFeaturesSelectionAlgorithm.RecursiveByShapValues,
#         shap_calc_type=EShapCalcType.Regular,
#         train_final_model=False,
#         plot=True,
#     )

#     print("Valid Model Training on Selected Features Subset.")
#     ctb_model = CatBoostRegressor(**ctb_params)
#     ctb_model.fit(
#         df_offline_train[summary['selected_features_names']], df_offline_train_target,
#         eval_set=[(df_offline_valid[summary['selected_features_names']], df_offline_valid_target)],
#         use_best_model=True,
#     )

#     del df_offline_train, df_offline_valid, df_offline_train_target, df_offline_valid_target
#     gc.collect()

#     print("Infer Model Training on Selected Features Subset.")
#     infer_params = ctb_params.copy()
#     # CatBoost train best with Valid number of iterations
#     infer_params["iterations"] = ctb_model.best_iteration_
#     infer_ctb_model = CatBoostRegressor(**infer_params)
#     infer_ctb_model.fit(df_train_feats[summary['selected_features_names']], df_train_target)
#     print("Infer Model Training on Selected Features Subset Complete.")

#     if is_offline:
#         # Offline predictions
#         df_valid_target = df_valid["target"]
#         offline_predictions = infer_ctb_model.predict(df_valid_feats[summary['selected_features_names']])
#         offline_score = mean_absolute_error(offline_predictions, df_valid_target)
#         print(f"Offline Score {np.round(offline_score, 4)}")

# %%
# summary['eliminated_features_names']

# %%
# feat_importances = infer_ctb_model.get_feature_importance(prettified=True)

# plt.figure(figsize=(12, 20))
# sns.barplot(x="Importances", y="Feature Id", data=feat_importances)
# plt.title('CatBoost features importance:')
# plt.tight_layout()

# %%
# from catboost import EFstrType
# feat_interactions = infer_ctb_model.get_feature_importance(type=EFstrType.Interaction, prettified=True)
# top_interactions = feat_interactions[:10]
# top_interactions

# %%
# top_interactions['First Feature Index'] = top_interactions['First Feature Index'].apply(lambda x: summary['selected_features_names'][x])
# top_interactions['Second Feature Index'] = top_interactions['Second Feature Index'].apply(lambda x: summary['selected_features_names'][x])
# top_interactions.columns = ['First Feature', 'Second Feature', 'Interaction']
# top_interactions

# %%
del_list=['PCA_WAP_3',
 'global_std_price',
 'PCA_WAP_2',
 'dow',
 'near_price_wap_imb',
 'weighted_wap',
 'near_price_diff_10',
 'ask_price_wap_imb',
 'dom',
 'matched_size_ret_3',
 'reference_price_ret_10',
 'wap_diff_10',
 'matched_size_ret_5',
 'rolling_diff_bid_price_3',
 'reference_price_far_price_imb',
 'all_prices_skew',
 'global_ptp_size',
 'rolling_std_diff_ask_price_5',
 'PCA_WAP_4',
 'PCA_WAP_1',
 'cluster',
 'global_median_price',
 'all_prices_mean',
 'global_std_size',
 'all_prices_kurt',
 'stock_id',
 'matched_size_shift_10',
 'rolling_std_diff_bid_price_3',
 'rolling_std_diff_bid_price_5',
 'stock_weights',
 'rolling_std_diff_ask_size_3',
 'depth_pressure',
 'spread_depth_ratio',
 'bid_size_diff_10',
 'near_price_bid_price_imb',
 'global_ptp_price',
 'far_price_near_price_imb',
 'imbalance_buy_sell_flag_shift_3',
 'rolling_std_diff_bid_price_10',
 'ask_price_bid_price_reference_price_imb2',
 'size_imbalance',
 'mid_price',
 'near_price',
 'rolling_std_diff_ask_price_10',
 'ask_price_bid_price_imb',
 'rolling_diff_bid_size_10',
 'bid_price_diff_2',
 'matched_size_shift_5']

# ['PCA_WAP_3',
#  'global_std_price',
#  'PCA_WAP_2',
#  'dow',
#  'near_price_wap_imb',
#  'weighted_wap',
#  'near_price_diff_10',
#  'ask_price_wap_imb',
#  'dom',
#  'matched_size_ret_3',
#  'reference_price_ret_10',
#  'wap_diff_10',
#  'matched_size_ret_5',
#  'rolling_diff_bid_price_3',
#  'reference_price_far_price_imb',
#  'all_prices_skew',
#  'global_ptp_size',
#  'rolling_std_diff_ask_price_5',
#  'rolling_std_diff_bid_price_3',
#  'far_price_bid_price_imb',
#  'far_price_wap_imb',
#  'reference_price_ret_3',
#  'rolling_std_diff_bid_price_10',
#  'rolling_std_diff_ask_price_3',
#  'matched_size_shift_5',
#  'stock_weights',
#  'all_prices_kurt',
#  'bid_price_diff_2',
#  'rolling_diff_bid_size_5',
#  'ask_size_diff_2',
#  'rolling_std_diff_ask_price_10',
#  'global_std_size',
#  'volume',
#  'reference_price_shift_3',
#  'PCA_WAP_4',
#  'all_prices_mean',
#  'global_ptp_price',
#  'reference_price_near_price_imb',
#  'cluster',
#  'near_price_diff_1',
#  'bid_price_diff_3',
#  'size_imbalance',
#  'stock_id',
#  'rolling_std_diff_bid_price_5',
#  'matched_size_shift_10',
#  'far_price',
#  'far_price_diff_3',
#  'bid_price_diff_10',
#  'spread_depth_ratio',
#  'bid_size_diff_10',
#  'imbalance_size_shift_2',
#  'far_price_ask_price_imb',
#  'imbalance_buy_sell_flag_ret_1',
#  'imbalance_buy_sell_flag_ret_2',
#  'imbalance_buy_sell_flag_ret_5',
#  'imbalance_buy_sell_flag_ret_10',
#  'size_change_diff_5',
#  'rolling_diff_bid_size_3',
#  'mid_price_movement',
#  'bid_size_diff_5',
#  'matched_size_shift_3',
#  'global_median_price',
#  'near_price',
#  'ask_price_bid_price_reference_price_imb2',
#  'ask_price_diff_3',
#  'rolling_diff_bid_price_5',
#  'depth_pressure',
#  'ask_price_diff_10',
#  'matched_size',
#  'price_spread',
#  'matched_size_ret_10',
#  'bid_price_diff_5',
#  'ask_size_diff_5',
#  'reference_price',
#  'rolling_diff_bid_size_10',
#  'ask_size_diff_3',
#  'rolling_diff_ask_size_5',
#  'liquidity_imbalance',
#  'reference_price_ret_2',
#  'rolling_diff_ask_size_3',
#  'imbalance_buy_sell_flag_ret_3',
#  'minute',
#  'bid_size_diff_3',
#  'ask_size_diff_10']

# %%
df_train_feats.drop(del_list,axis=1,inplace=True)
df_valid_feats.drop(del_list,axis=1,inplace=True)
feature_name = list(df_train_feats.columns)
print(f"Feature length = {len(feature_name)}")
# Out:
# Feature length = 136

# %%
feature_name = list(df_train_feats.columns)
print(f"Feature length = {len(feature_name)}")
# Out:
# Feature length = 136

# %%
# # Set LightGBM parameters
# lgb_params = {
#     "objective": "mae",
#     "n_estimators": 5000, #less estimators
#     "num_leaves": 256, #more leaves
#     "subsample": 0.6,
#     "colsample_bytree": 0.6,
#     "learning_rate": 0.00871, #larger learning rate(from 0.00871 to 0.00005)
#     'max_depth': 11,
#     "n_jobs": 4,
#     "device": "gpu",
#     "verbosity": -1,
#     "importance_type": "gain",
# }
# # Get feature names
# feature_name = list(df_train_feats.columns)
# print(f"Feature length = {len(feature_name)}")

# # Set up cross-validation parameters
# num_folds = 5
# fold_size = 435 // num_folds #offline mode
# gap = 5

# # Initialize lists to store models and scores
# models = []
# scores = []

# # Set model save path
# model_save_path = 'modelitos_para_despues'
# if not os.path.exists(model_save_path):
#     os.makedirs(model_save_path)

# # Get date IDs from the training data
# date_ids = df_train['date_id'].values

# # Loop over folds for cross-validation
# for i in range(num_folds):
#     start = i * fold_size
#     end = start + fold_size
    
#     # Define the purged set ranges
#     purged_before_start = start - 2
#     purged_before_end = start + 2
#     purged_after_start = end - 2
#     purged_after_end = end + 2
    
#     # Exclude the purged ranges from the test set
#     purged_set = ((date_ids >= purged_before_start) & (date_ids <= purged_before_end)) | \
#                  ((date_ids >= purged_after_start) & (date_ids <= purged_after_end))
    
#     # Define test_indices excluding the purged set
#     test_indices = (date_ids >= start) & (date_ids < end) & ~purged_set
#     train_indices = ~test_indices & ~purged_set

#     # Create fold-specific training and validation sets
#     df_fold_train = df_train_feats[train_indices]
#     df_fold_train_target = df_train['target'][train_indices]
#     df_fold_valid = df_train_feats[test_indices]
#     df_fold_valid_target = df_train['target'][test_indices]

#     print(f"Fold {i+1} Model Training")

#     # Train a LightGBM model for the current fold
#     lgb_model = lgb.LGBMRegressor(**lgb_params)
#     lgb_model.fit(
#         df_fold_train[feature_name],
#         df_fold_train_target,
#         eval_set=[(df_fold_valid[feature_name], df_fold_valid_target)],
#         callbacks=[
#             lgb.callback.early_stopping(stopping_rounds=100),
#             lgb.callback.log_evaluation(period=100),
#         ],
#     )

#     models.append(lgb_model)

#     # Save the model to a file
#     model_filename = os.path.join(model_save_path, f'doblez_{i+1}.txt')
#     lgb_model.booster_.save_model(model_filename)
#     print(f"Model for fold {i+1} saved to {model_filename}")

#     # Evaluate model performance on the validation set
#     fold_predictions = lgb_model.predict(df_fold_valid[feature_name])
#     fold_score = mean_absolute_error(fold_predictions, df_fold_valid_target)
#     scores.append(fold_score)
#     print(f"Fold {i+1} MAE: {fold_score}")

#     # Free up memory by deleting fold-specific variables
#     del df_fold_train, df_fold_train_target, df_fold_valid, df_fold_valid_target
#     gc.collect()

# # Calculate the average best iteration from all regular folds
# average_best_iteration = int(np.mean([model.best_iteration_ for model in models]))

# # Update the lgb_params with the average best iteration
# final_model_params = lgb_params.copy()
# final_model_params['n_estimators'] = average_best_iteration

# print(f"Training final model with average best iteration: {average_best_iteration}")

# # Train the final model on the entire dataset
# final_model = lgb.LGBMRegressor(**final_model_params)
# final_model.fit(
#     df_train_feats[feature_name],
#     df_train['target'],
#     callbacks=[
#         lgb.callback.log_evaluation(period=100),
#     ],
# )
# # Append the final model to the list of models
# models.append(final_model)

# # Append the final model to the list of models
# models.append(final_model)

# # Save the final model to a file
# final_model_filename = os.path.join(model_save_path, 'doblez-conjunto.txt')
# final_model.booster_.save_model(final_model_filename)
# print(f"Final model saved to {final_model_filename}")

# # Now 'models' holds the trained models for each fold and 'scores' holds the validation scores
# print(f"Average MAE across all folds: {np.mean(scores)}")

# if is_offline:
#     # offline predictions
#     df_valid_target = df_valid["target"]
#     offline_predictions = final_model.predict(df_valid_feats[feature_name])
#     offline_score = mean_absolute_error(offline_predictions, df_valid_target)
#     print(f"Offline Score {np.round(offline_score, 4)}")

# %% [markdown]
# ###4.2 Recursive Feature Elimination with Stratified K-Fold CV

# %%
# from sklearn.feature_selection import RFECV
# from sklearn.model_selection import StratifiedKFold


# # Train procedure
# if is_train:
#     offline_split = df_train['date_id']>(split_day - 45)
#     df_offline_train = df_train_feats[~offline_split]
#     df_offline_valid = df_train_feats[offline_split]
#     df_offline_train_target = df_train['target'][~offline_split]
#     df_offline_valid_target = df_train['target'][offline_split]
#     df_train_target = df_train["target"]
#     del df_train
#     gc.collect()

#     lgb_params = {
#         "objective" : "mae",
#         "n_estimators" : 3000,
#         "num_leaves" : 128,
#         "subsample" : 0.6,
#         "colsample_bytree" : 0.6,
#         "learning_rate" : 0.05,
#         "n_jobs" : 4,
#         "device" : "gpu",
#         "verbosity": -1,
#         "importance_type" : "gain",
#     }


#     min_features_to_select = 120 #Minimum number of features to consider
#     lgb = lgb.LGBMRegressor(**lgb_params)
#     cv = StratifiedKFold(10) #Assign 10 clusters to stocks


#     print("Feature Elimination Performing.")
#     rfecv = RFECV(
#         estimator = lgb,
#         step = 9, #greater than 1 corresponds to num of feas to remove, within (0.0, 1.0) then corresponds to removal percantage
#         cv = cv,
#         scoring = 'accuracy',
#         min_features_to_select = min_features_to_select,
#         n_jobs = 2, #number of cores to run
#     )


#     rfecv.fit(
#         df_offline_train,
#         df_offline_train_target,
#     )

#     print("Valid Model Training on Selected Features Subset.")
#     selected_feas = df_offline_train.columns[rfecv.support_] #slected features

#     lgb = lgb.LGBMRegrssor(**lgb_params)
#     lgb.fit(
#         df_offline_train[selected_feas],
#         df_offline_train_target,
#         eval_set=[(df_offline_valid[selected_feas], df_offline_valid_target)],
#         callbacks = [
#             lgb.callback.early_stopping(stopping_rounds=100),
#             lgb.callback.log_evaluation(period=100),
#         ]

#     )

#     del df_offline_train, df_offline_valid, df_offline_train_target, df_offline_valid_target
#     gc.collect()

#     print("Infer Model Trainning.")
#     infer_params = lgb_params.copy()
#     infer_params["n_estimators"] = int(1.2 * lgb.best_iteration_)
#     infer_lgb_model = lgb.LGBMRegressor(**infer_params)
#     infer_lgb_model.fit(df_train_feats[selected_feas], df_train_target)
#     print("Infer Model Training on Selected Features Subset Complete.")

#     if is_offline:
#         # Offline predictions
#         df_valid_target = df_valid["target"]
#         offline_predictions = infer_lgb_model.predict(df_valid_feats[selected_feats])
#         offline_score = mean_absolute_error(offline_predictions, df_valid_target)
#         print(f"Offline Score {np.round(offline_score, 4)}")

#         del df_valid, df_valid_feats
#         gc.collect()

#     del df_train_feats
#     gc.collect()

# %%
import pandas as pd
import xgboost as xgb
import lightgbm as lgb
import catboost as ctb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

# lgb_cv_params = {
#     'n_estimators':range(2000,5000),
# }

# lgb_params = {
# #     'n_estimators':300,
#     'max_depth':9, #一般这个值设为7-10即可
#     'num_leaves':256, #要小于2**max_depth，比如2**7也就是128，
#     'learning_rate':0.00871,
#     'subsample':0.6,
#     'feature_frequency':0.8,
#     'random_state':32,
#     'class_weight':'balanced',
#     'n_jobs':4,
#     'subsample_freq':2
# }

# lgb_cv = GridSearchCV(lgb.LGBMClassifier(**lgb_params), 
#                       lgb_cv_params,
#                       scoring='accuracy',
#                       cv=5,
#                       n_jobs=-1)

# lgb_cv.fit(df_train_feats, df_train['target'])

# print(lgb_cv.best_params_)
# print(lgb_cv.best_score_)

# %%
import numpy as np

oof_lgb = np.zeros(df_train_feats.shape[0])
oof_xgb = np.zeros(df_train_feats.shape[0])
oof_cat = np.zeros(df_train_feats.shape[0])

test_output_df = pd.DataFrame(columns=['lgb','xgb','cat'],index=range(df_valid_feats.shape[0]))
test_output_df = test_output_df.fillna(0)

# %%
lgb_reg = lgb.LGBMRegressor(max_depth=9,
                           n_estimators=5000,
                           subsample=0.6,
                           colsample_bytree=0.6,
                           random_state=32)

cat_reg = ctb.CatBoostRegressor(learning_rate=0.00871,
                               depth=9,
                               random_seed=32,
                               )

xgb_reg = xgb.XGBRegressor(max_depth=9,
                          learning_rate=0.00871,
                          n_estimators=5000,
                          n_jobs=4,
                          colsample_bytree=0.6,
                          subsample=0.6,
                          random_state=32,
                          )

# %%
# Set up cross-validation parameters
num_folds = 5
fold_size = 435 // num_folds #offline mode
gap = 5

# Initialize lists to store models and scores
model_lgb = []
model_xgb = []
model_cat = []
score_lgb = []
score_xgb = []
score_cat = []
# Set model save path
model_save_path = 'modelitos_para_despues'
if not os.path.exists(model_save_path):
    os.makedirs(model_save_path)

# Get date IDs from the training data
date_ids = df_train['date_id'].values

# Loop over folds for cross-validation
for i in range(num_folds):
    start = i * fold_size
    end = start + fold_size
    
    # Define the purged set ranges
    purged_before_start = start - 2
    purged_before_end = start + 2
    purged_after_start = end - 2
    purged_after_end = end + 2
    
    # Exclude the purged ranges from the test set
    purged_set = ((date_ids >= purged_before_start) & (date_ids <= purged_before_end)) | \
                 ((date_ids >= purged_after_start) & (date_ids <= purged_after_end))
    
    # Define test_indices excluding the purged set
    test_indices = (date_ids >= start) & (date_ids < end) & ~purged_set
    train_indices = ~test_indices & ~purged_set

    # Create fold-specific training and validation sets
    train_x = df_train_feats[train_indices]
    train_y = df_train['target'][train_indices]
    valid_x = df_train_feats[test_indices]
    valid_y = df_train['target'][test_indices]

    print(f"Fold {i+1} Model Training")
    
    lgb_reg.fit(train_x,train_y, eval_set=[(train_x,train_y),(valid_x,valid_y)],early_stopping_rounds=100)
    xgb_reg.fit(train_x,train_y, eval_set=[(train_x,train_y),(valid_x,valid_y)],early_stopping_rounds=100)
    cat_reg.fit(train_x,train_y, eval_set=[(train_x,train_y),(valid_x,valid_y)],early_stopping_rounds=100)
    model_lgb.append(lgb_reg)
    model_xgb.append(xgb_reg)
    model_cat.append(cat_reg)
    # Save the model to a file
    model_filename = os.path.join(model_save_path, f'doblez_{i+1}.txt')
    lgb_reg.booster_.save_model(model_filename)
    xgb_reg.booster_.save_model(model_filename)
    cat_reg.booster_.save_model(model_filename)
    print(f"Models for fold {i+1} saved to {model_filename}")
    
    # Evaluate model performance on the validation set
    
    fold_score = mean_absolute_error(fold_predictions, df_fold_valid_target)
    scores.append(fold_score)
    print(f"Fold {i+1} MAE: {fold_score}")
    oof_lgb[valid_idx] = lgb_reg.predict(valid_x)
    oof_xgb[valid_idx] = xgb_reg.predict(valid_x)
    oof_cat[valid_idx] = cat_reg.predict(valid_x)
    fold_score_lgb = mean_absolute_error(oof_lgb[valid_idx], valid_y)
    fold_score_xgb = mean_absolute_error(oof_xgb[valid_idx], valid_y)
    fold_score_cat = mean_absolute_error(oof_cat[valid_idx], valid_y)
    score_lgb.append(fold_score_lgb)
    score_xgb.append(fold_score_xgb)
    score_cat.append(fold_score_cat)
    print(f"Fold {i+1} LGB MAE: {fold_score_lgb}")
    print(f"Fold {i+1} XGB MAE: {fold_score_xgb}")
    print(f"Fold {i+1} CAT MAE: {fold_score_cat}")
    
    test_output_df['lgb'] += lgb_reg.predict(df_valid_feats)
    test_output_df['xgb'] += xgb_reg.predict(df_valid_feats)
    test_output_df['cat'] += cat_reg.predict(df_valid_feats)
    
    del train_x, train_y, valid_x, valid_y
    gc.collect()
    

test_output_df['lgb'] = test_output_df['lgb'] / 5
test_output_df['xgb'] = test_output_df['xgb'] / 5
test_output_df['cat'] = test_output_df['cat'] / 5
# Out:
# Fold 1 Model Training
# [1]	training's l2: 94.0501	valid_1's l2: 71.2627
# [2]	training's l2: 93.6497	valid_1's l2: 70.8996
# [3]	training's l2: 93.3092	valid_1's l2: 70.576
# [4]	training's l2: 93.039	valid_1's l2: 70.3492
# [5]	training's l2: 92.8095	valid_1's l2: 70.1314
# [6]	training's l2: 92.6137	valid_1's l2: 69.9543
# [7]	training's l2: 92.4489	valid_1's l2: 69.8166
# [8]	training's l2: 92.2849	valid_1's l2: 69.6811
# [9]	training's l2: 92.148	valid_1's l2: 69.5654
# [10]	training's l2: 92.0267	valid_1's l2: 69.4653
# [11]	training's l2: 91.9235	valid_1's l2: 69.3889
# [12]	training's l2: 91.8379	valid_1's l2: 69.3229
# [13]	training's l2: 91.7564	valid_1's l2: 69.2622
# [14]	training's l2: 91.68	valid_1's l2: 69.2122
# [15]	training's l2: 91.6115	valid_1's l2: 69.1651
# [16]	training's l2: 91.5507	valid_1's l2: 69.122
# [17]	training's l2: 91.4888	valid_1's l2: 69.0879
# [436]	training's l2: 85.4213	valid_1's l2: 68.217
# [437]	training's l2: 85.4105	valid_1's l2: 68.2171
# [438]	training's l2: 85.4039	valid_1's l2: 68.2182
# [439]	training's l2: 85.3925	valid_1's l2: 68.2218
# [440]	training's l2: 85.3896	valid_1's l2: 68.222
# [441]	training's l2: 85.3853	valid_1's l2: 68.2223
# [442]	training's l2: 85.3768	valid_1's l2: 68.222
# [443]	training's l2: 85.3697	valid_1's l2: 68.2231
# [444]	training's l2: 85.361	valid_1's l2: 68.2237
# [445]	training's l2: 85.3544	valid_1's l2: 68.2248
# [446]	training's l2: 85.3486	valid_1's l2: 68.2238
# [447]	training's l2: 85.3456	valid_1's l2: 68.2238
# [448]	training's l2: 85.3437	valid_1's l2: 68.2237
# [449]	training's l2: 85.3355	valid_1's l2: 68.2212
# [450]	training's l2: 85.3245	valid_1's l2: 68.2236
# [451]	training's l2: 85.3192	valid_1's l2: 68.2241
# [452]	training's l2: 85.3099	valid_1's l2: 68.2274
# [453]	training's l2: 85.3042	valid_1's l2: 68.2275
# [454]	training's l2: 85.2968	valid_1's l2: 68.2236
# [455]	training's l2: 85.2886	valid_1's l2: 68.2245
# [456]	training's l2: 85.2792	valid_1's l2: 68.2244
# [457]	training's l2: 85.2723	valid_1's l2: 68.2255
# [458]	training's l2: 85.2641	valid_1's l2: 68.2276
# [459]	training's l2: 85.2587	valid_1's l2: 68.2279
# [460]	training's l2: 85.2499	valid_1's l2: 68.2306
# [461]	training's l2: 85.247	valid_1's l2: 68.2304
# [462]	training's l2: 85.2403	valid_1's l2: 68.2269
# [463]	training's l2: 85.2329	valid_1's l2: 68.2252
# [464]	training's l2: 85.2247	valid_1's l2: 68.2195
# [465]	training's l2: 85.2191	valid_1's l2: 68.219
# [466]	training's l2: 85.2123	valid_1's l2: 68.2194
# [467]	training's l2: 85.2012	valid_1's l2: 68.2172
# [468]	training's l2: 85.1973	valid_1's l2: 68.2187
# [469]	training's l2: 85.1937	valid_1's l2: 68.2196
# [470]	training's l2: 85.1894	valid_1's l2: 68.2214
# [471]	training's l2: 85.1827	valid_1's l2: 68.2229
# [472]	training's l2: 85.1759	valid_1's l2: 68.2226
# [473]	training's l2: 85.1671	valid_1's l2: 68.2211
# [474]	training's l2: 85.1573	valid_1's l2: 68.2227
# [475]	training's l2: 85.1518	valid_1's l2: 68.224
# [476]	training's l2: 85.1475	valid_1's l2: 68.2248
# [477]	training's l2: 85.145	valid_1's l2: 68.2247
# [478]	training's l2: 85.139	valid_1's l2: 68.2248
# [0]	validation_0-rmse:9.72085	validation_1-rmse:8.46674
# [1]	validation_0-rmse:9.71761	validation_1-rmse:8.46395
# [2]	validation_0-rmse:9.71441	validation_1-rmse:8.46125
# [3]	validation_0-rmse:9.71146	validation_1-rmse:8.45881
# [4]	validation_0-rmse:9.70828	validation_1-rmse:8.45612
# [5]	validation_0-rmse:9.70521	validation_1-rmse:8.45348
# [6]	validation_0-rmse:9.70238	validation_1-rmse:8.45109
# [7]	validation_0-rmse:9.69945	validation_1-rmse:8.44854
# [8]	validation_0-rmse:9.69636	validation_1-rmse:8.44595
# [9]	validation_0-rmse:9.69345	validation_1-rmse:8.44346
# [10]	validation_0-rmse:9.69059	validation_1-rmse:8.44114
# [11]	validation_0-rmse:9.68761	validation_1-rmse:8.43869
# [12]	validation_0-rmse:9.68486	validation_1-rmse:8.43635
# [13]	validation_0-rmse:9.68208	validation_1-rmse:8.43413
# [14]	validation_0-rmse:9.67927	validation_1-rmse:8.43187
# [15]	validation_0-rmse:9.67653	validation_1-rmse:8.42953
# [16]	validation_0-rmse:9.67384	validation_1-rmse:8.42737
# [17]	validation_0-rmse:9.67121	validation_1-rmse:8.42531
# [18]	validation_0-rmse:9.66851	validation_1-rmse:8.42318
# [19]	validation_0-rmse:9.66599	validation_1-rmse:8.42116
# [20]	validation_0-rmse:9.66336	validation_1-rmse:8.41902
# [21]	validation_0-rmse:9.66074	validation_1-rmse:8.41706
# [22]	validation_0-rmse:9.65830	validation_1-rmse:8.41517
# [23]	validation_0-rmse:9.65592	validation_1-rmse:8.41327
# [24]	validation_0-rmse:9.65361	validation_1-rmse:8.41145
# [25]	validation_0-rmse:9.65123	validation_1-rmse:8.40951
# [26]	validation_0-rmse:9.64895	validation_1-rmse:8.40782
# [27]	validation_0-rmse:9.64662	validation_1-rmse:8.40613
# [28]	validation_0-rmse:9.64420	validation_1-rmse:8.40431
# [29]	validation_0-rmse:9.64217	validation_1-rmse:8.40275
# [30]	validation_0-rmse:9.63993	validation_1-rmse:8.40098
# [31]	validation_0-rmse:9.63765	validation_1-rmse:8.39925
# [32]	validation_0-rmse:9.63551	validation_1-rmse:8.39758
# [33]	validation_0-rmse:9.63323	validation_1-rmse:8.39583
# [34]	validation_0-rmse:9.63114	validation_1-rmse:8.39423
# [35]	validation_0-rmse:9.62905	validation_1-rmse:8.39266
# [36]	validation_0-rmse:9.62703	validation_1-rmse:8.39112
# [37]	validation_0-rmse:9.62489	validation_1-rmse:8.38951
# [38]	validation_0-rmse:9.62281	validation_1-rmse:8.38788
# [39]	validation_0-rmse:9.62068	validation_1-rmse:8.38632
# [40]	validation_0-rmse:9.61866	validation_1-rmse:8.38492
# [41]	validation_0-rmse:9.61663	validation_1-rmse:8.38339
# [42]	validation_0-rmse:9.61460	validation_1-rmse:8.38190
# [43]	validation_0-rmse:9.61263	validation_1-rmse:8.38047
# [44]	validation_0-rmse:9.61062	validation_1-rmse:8.37902
# [45]	validation_0-rmse:9.60878	validation_1-rmse:8.37775
# [46]	validation_0-rmse:9.60689	validation_1-rmse:8.37639
# [47]	validation_0-rmse:9.60514	validation_1-rmse:8.37511
# [48]	validation_0-rmse:9.60331	validation_1-rmse:8.37381
# [49]	validation_0-rmse:9.60148	validation_1-rmse:8.37245
# [50]	validation_0-rmse:9.59984	validation_1-rmse:8.37135
# [51]	validation_0-rmse:9.59813	validation_1-rmse:8.37010
# [52]	validation_0-rmse:9.59626	validation_1-rmse:8.36879
# [53]	validation_0-rmse:9.59457	validation_1-rmse:8.36745
# [54]	validation_0-rmse:9.59283	validation_1-rmse:8.36622
# [55]	validation_0-rmse:9.59111	validation_1-rmse:8.36495
# [56]	validation_0-rmse:9.58933	validation_1-rmse:8.36368
# [57]	validation_0-rmse:9.58768	validation_1-rmse:8.36246
# [58]	validation_0-rmse:9.58605	validation_1-rmse:8.36137
# [59]	validation_0-rmse:9.58451	validation_1-rmse:8.36019
# [60]	validation_0-rmse:9.58280	validation_1-rmse:8.35905
# [61]	validation_0-rmse:9.58119	validation_1-rmse:8.35797
# [62]	validation_0-rmse:9.57968	validation_1-rmse:8.35685
# [63]	validation_0-rmse:9.57815	validation_1-rmse:8.35580
# [64]	validation_0-rmse:9.57646	validation_1-rmse:8.35479
# [65]	validation_0-rmse:9.57491	validation_1-rmse:8.35371
# [66]	validation_0-rmse:9.57333	validation_1-rmse:8.35269
# [67]	validation_0-rmse:9.57180	validation_1-rmse:8.35177
# [68]	validation_0-rmse:9.57035	validation_1-rmse:8.35069
# [69]	validation_0-rmse:9.56880	validation_1-rmse:8.34973
# [70]	validation_0-rmse:9.56736	validation_1-rmse:8.34877
# [71]	validation_0-rmse:9.56602	validation_1-rmse:8.34790
# [72]	validation_0-rmse:9.56467	validation_1-rmse:8.34700
# [73]	validation_0-rmse:9.56321	validation_1-rmse:8.34609
# [74]	validation_0-rmse:9.56181	validation_1-rmse:8.34518
# [75]	validation_0-rmse:9.56037	validation_1-rmse:8.34437
# [76]	validation_0-rmse:9.55911	validation_1-rmse:8.34365
# [77]	validation_0-rmse:9.55764	validation_1-rmse:8.34265
# [78]	validation_0-rmse:9.55621	validation_1-rmse:8.34176
# [79]	validation_0-rmse:9.55479	validation_1-rmse:8.34091
# [80]	validation_0-rmse:9.55343	validation_1-rmse:8.34012
# [81]	validation_0-rmse:9.55205	validation_1-rmse:8.33929
# [82]	validation_0-rmse:9.55072	validation_1-rmse:8.33853
# [83]	validation_0-rmse:9.54938	validation_1-rmse:8.33778
# [84]	validation_0-rmse:9.54799	validation_1-rmse:8.33701
# [85]	validation_0-rmse:9.54665	validation_1-rmse:8.33626
# [86]	validation_0-rmse:9.54545	validation_1-rmse:8.33548
# [87]	validation_0-rmse:9.54418	validation_1-rmse:8.33465
# [88]	validation_0-rmse:9.54283	validation_1-rmse:8.33377
# [89]	validation_0-rmse:9.54154	validation_1-rmse:8.33307
# [90]	validation_0-rmse:9.54030	validation_1-rmse:8.33236
# [91]	validation_0-rmse:9.53907	validation_1-rmse:8.33175
# [92]	validation_0-rmse:9.53785	validation_1-rmse:8.33109
# [93]	validation_0-rmse:9.53655	validation_1-rmse:8.33040
# [94]	validation_0-rmse:9.53546	validation_1-rmse:8.32986
# [95]	validation_0-rmse:9.53424	validation_1-rmse:8.32924
# [96]	validation_0-rmse:9.53299	validation_1-rmse:8.32851
# [97]	validation_0-rmse:9.53184	validation_1-rmse:8.32795
# [98]	validation_0-rmse:9.53070	validation_1-rmse:8.32735
# [99]	validation_0-rmse:9.52941	validation_1-rmse:8.32660
# [100]	validation_0-rmse:9.52821	validation_1-rmse:8.32603
# [101]	validation_0-rmse:9.52703	validation_1-rmse:8.32541
# [102]	validation_0-rmse:9.52598	validation_1-rmse:8.32486
# [103]	validation_0-rmse:9.52482	validation_1-rmse:8.32426
# [104]	validation_0-rmse:9.52362	validation_1-rmse:8.32362
# [105]	validation_0-rmse:9.52251	validation_1-rmse:8.32302
# [106]	validation_0-rmse:9.52140	validation_1-rmse:8.32240
# [107]	validation_0-rmse:9.52026	validation_1-rmse:8.32185
# [108]	validation_0-rmse:9.51925	validation_1-rmse:8.32127
# [109]	validation_0-rmse:9.51807	validation_1-rmse:8.32075
# [110]	validation_0-rmse:9.51692	validation_1-rmse:8.32023
# [111]	validation_0-rmse:9.51589	validation_1-rmse:8.31974
# [112]	validation_0-rmse:9.51482	validation_1-rmse:8.31919
# [113]	validation_0-rmse:9.51378	validation_1-rmse:8.31867
# [114]	validation_0-rmse:9.51281	validation_1-rmse:8.31814
# [115]	validation_0-rmse:9.51179	validation_1-rmse:8.31760
# [116]	validation_0-rmse:9.51065	validation_1-rmse:8.31699
# [117]	validation_0-rmse:9.50960	validation_1-rmse:8.31645
# [118]	validation_0-rmse:9.50867	validation_1-rmse:8.31604
# [119]	validation_0-rmse:9.50759	validation_1-rmse:8.31545
# [120]	validation_0-rmse:9.50656	validation_1-rmse:8.31492
# [121]	validation_0-rmse:9.50563	validation_1-rmse:8.31443
# [122]	validation_0-rmse:9.50456	validation_1-rmse:8.31396
# [123]	validation_0-rmse:9.50359	validation_1-rmse:8.31349
# [124]	validation_0-rmse:9.50268	validation_1-rmse:8.31294
# [125]	validation_0-rmse:9.50175	validation_1-rmse:8.31255
# [126]	validation_0-rmse:9.50075	validation_1-rmse:8.31207
# [127]	validation_0-rmse:9.49986	validation_1-rmse:8.31165
# [128]	validation_0-rmse:9.49893	validation_1-rmse:8.31119
# [129]	validation_0-rmse:9.49806	validation_1-rmse:8.31077
# [130]	validation_0-rmse:9.49711	validation_1-rmse:8.31026
# [131]	validation_0-rmse:9.49620	validation_1-rmse:8.30983
# [132]	validation_0-rmse:9.49528	validation_1-rmse:8.30938
# [133]	validation_0-rmse:9.49440	validation_1-rmse:8.30890
# [134]	validation_0-rmse:9.49350	validation_1-rmse:8.30845
# [135]	validation_0-rmse:9.49261	validation_1-rmse:8.30800
# [136]	validation_0-rmse:9.49167	validation_1-rmse:8.30749
# [137]	validation_0-rmse:9.49079	validation_1-rmse:8.30707
# [138]	validation_0-rmse:9.48983	validation_1-rmse:8.30663
# [139]	validation_0-rmse:9.48889	validation_1-rmse:8.30615
# [140]	validation_0-rmse:9.48800	validation_1-rmse:8.30578
# [141]	validation_0-rmse:9.48705	validation_1-rmse:8.30533
# [142]	validation_0-rmse:9.48619	validation_1-rmse:8.30495
# [143]	validation_0-rmse:9.48529	validation_1-rmse:8.30455
# [144]	validation_0-rmse:9.48433	validation_1-rmse:8.30418
# [145]	validation_0-rmse:9.48350	validation_1-rmse:8.30383
# [146]	validation_0-rmse:9.48255	validation_1-rmse:8.30343
# [147]	validation_0-rmse:9.48179	validation_1-rmse:8.30305
# [148]	validation_0-rmse:9.48091	validation_1-rmse:8.30276
# [149]	validation_0-rmse:9.48014	validation_1-rmse:8.30248
# [150]	validation_0-rmse:9.47929	validation_1-rmse:8.30215
# [151]	validation_0-rmse:9.47845	validation_1-rmse:8.30183
# [152]	validation_0-rmse:9.47759	validation_1-rmse:8.30160
# [153]	validation_0-rmse:9.47677	validation_1-rmse:8.30131
# [154]	validation_0-rmse:9.47591	validation_1-rmse:8.30096
# [155]	validation_0-rmse:9.47516	validation_1-rmse:8.30053
# [156]	validation_0-rmse:9.47424	validation_1-rmse:8.30008
# [157]	validation_0-rmse:9.47343	validation_1-rmse:8.29969
# [158]	validation_0-rmse:9.47259	validation_1-rmse:8.29937
# [159]	validation_0-rmse:9.47185	validation_1-rmse:8.29902
# [160]	validation_0-rmse:9.47107	validation_1-rmse:8.29874
# [161]	validation_0-rmse:9.47031	validation_1-rmse:8.29850
# [162]	validation_0-rmse:9.46957	validation_1-rmse:8.29816
# [163]	validation_0-rmse:9.46885	validation_1-rmse:8.29787
# [164]	validation_0-rmse:9.46809	validation_1-rmse:8.29751
# [165]	validation_0-rmse:9.46731	validation_1-rmse:8.29721
# [166]	validation_0-rmse:9.46655	validation_1-rmse:8.29693
# [167]	validation_0-rmse:9.46570	validation_1-rmse:8.29658
# [168]	validation_0-rmse:9.46497	validation_1-rmse:8.29629
# [169]	validation_0-rmse:9.46433	validation_1-rmse:8.29601
# [170]	validation_0-rmse:9.46352	validation_1-rmse:8.29576
# [171]	validation_0-rmse:9.46280	validation_1-rmse:8.29550
# [172]	validation_0-rmse:9.46207	validation_1-rmse:8.29524
# [173]	validation_0-rmse:9.46135	validation_1-rmse:8.29493
# [174]	validation_0-rmse:9.46060	validation_1-rmse:8.29475
# [175]	validation_0-rmse:9.45998	validation_1-rmse:8.29452
# [176]	validation_0-rmse:9.45918	validation_1-rmse:8.29432
# [177]	validation_0-rmse:9.45845	validation_1-rmse:8.29402
# [178]	validation_0-rmse:9.45776	validation_1-rmse:8.29378
# [179]	validation_0-rmse:9.45708	validation_1-rmse:8.29357
# [180]	validation_0-rmse:9.45643	validation_1-rmse:8.29339
# [181]	validation_0-rmse:9.45563	validation_1-rmse:8.29314
# [182]	validation_0-rmse:9.45501	validation_1-rmse:8.29293
# [183]	validation_0-rmse:9.45431	validation_1-rmse:8.29269
# [184]	validation_0-rmse:9.45364	validation_1-rmse:8.29241
# [185]	validation_0-rmse:9.45298	validation_1-rmse:8.29225
# [186]	validation_0-rmse:9.45230	validation_1-rmse:8.29210
# [187]	validation_0-rmse:9.45165	validation_1-rmse:8.29195
# [188]	validation_0-rmse:9.45089	validation_1-rmse:8.29174
# [189]	validation_0-rmse:9.45026	validation_1-rmse:8.29147
# [190]	validation_0-rmse:9.44955	validation_1-rmse:8.29141
# [191]	validation_0-rmse:9.44887	validation_1-rmse:8.29125
# [192]	validation_0-rmse:9.44823	validation_1-rmse:8.29107
# [193]	validation_0-rmse:9.44748	validation_1-rmse:8.29090
# [194]	validation_0-rmse:9.44684	validation_1-rmse:8.29071
# [195]	validation_0-rmse:9.44621	validation_1-rmse:8.29058
# [196]	validation_0-rmse:9.44565	validation_1-rmse:8.29034
# [197]	validation_0-rmse:9.44487	validation_1-rmse:8.29011
# [198]	validation_0-rmse:9.44433	validation_1-rmse:8.28992
# [199]	validation_0-rmse:9.44374	validation_1-rmse:8.28969
# [200]	validation_0-rmse:9.44310	validation_1-rmse:8.28946
# [201]	validation_0-rmse:9.44247	validation_1-rmse:8.28923
# [202]	validation_0-rmse:9.44177	validation_1-rmse:8.28908
# [203]	validation_0-rmse:9.44108	validation_1-rmse:8.28882
# [204]	validation_0-rmse:9.44043	validation_1-rmse:8.28864
# [205]	validation_0-rmse:9.43975	validation_1-rmse:8.28842
# [206]	validation_0-rmse:9.43917	validation_1-rmse:8.28817
# [207]	validation_0-rmse:9.43856	validation_1-rmse:8.28795
# [208]	validation_0-rmse:9.43787	validation_1-rmse:8.28771
# [209]	validation_0-rmse:9.43719	validation_1-rmse:8.28751
# [210]	validation_0-rmse:9.43657	validation_1-rmse:8.28732
# [211]	validation_0-rmse:9.43594	validation_1-rmse:8.28714
# [212]	validation_0-rmse:9.43525	validation_1-rmse:8.28692
# [213]	validation_0-rmse:9.43469	validation_1-rmse:8.28674
# [214]	validation_0-rmse:9.43405	validation_1-rmse:8.28653
# [215]	validation_0-rmse:9.43338	validation_1-rmse:8.28637
# [216]	validation_0-rmse:9.43285	validation_1-rmse:8.28629
# [217]	validation_0-rmse:9.43228	validation_1-rmse:8.28613
# [218]	validation_0-rmse:9.43158	validation_1-rmse:8.28591
# [219]	validation_0-rmse:9.43103	validation_1-rmse:8.28565
# [220]	validation_0-rmse:9.43038	validation_1-rmse:8.28541
# [221]	validation_0-rmse:9.42975	validation_1-rmse:8.28519
# [222]	validation_0-rmse:9.42904	validation_1-rmse:8.28494
# [223]	validation_0-rmse:9.42836	validation_1-rmse:8.28463
# [224]	validation_0-rmse:9.42775	validation_1-rmse:8.28438
# [225]	validation_0-rmse:9.42718	validation_1-rmse:8.28420
# [226]	validation_0-rmse:9.42658	validation_1-rmse:8.28405
# [227]	validation_0-rmse:9.42596	validation_1-rmse:8.28395
# [228]	validation_0-rmse:9.42540	validation_1-rmse:8.28379
# [229]	validation_0-rmse:9.42482	validation_1-rmse:8.28370
# [230]	validation_0-rmse:9.42429	validation_1-rmse:8.28350
# [231]	validation_0-rmse:9.42377	validation_1-rmse:8.28334
# [232]	validation_0-rmse:9.42308	validation_1-rmse:8.28311
# [233]	validation_0-rmse:9.42249	validation_1-rmse:8.28303
# [234]	validation_0-rmse:9.42184	validation_1-rmse:8.28287
# [235]	validation_0-rmse:9.42135	validation_1-rmse:8.28278
# [236]	validation_0-rmse:9.42080	validation_1-rmse:8.28266
# [237]	validation_0-rmse:9.42014	validation_1-rmse:8.28248
# [238]	validation_0-rmse:9.41963	validation_1-rmse:8.28231
# [239]	validation_0-rmse:9.41893	validation_1-rmse:8.28212
# [240]	validation_0-rmse:9.41835	validation_1-rmse:8.28201
# [241]	validation_0-rmse:9.41778	validation_1-rmse:8.28184
# [242]	validation_0-rmse:9.41713	validation_1-rmse:8.28166
# [243]	validation_0-rmse:9.41657	validation_1-rmse:8.28142
# [244]	validation_0-rmse:9.41600	validation_1-rmse:8.28130
# [245]	validation_0-rmse:9.41546	validation_1-rmse:8.28118
# [246]	validation_0-rmse:9.41490	validation_1-rmse:8.28105
# [247]	validation_0-rmse:9.41437	validation_1-rmse:8.28098
# [248]	validation_0-rmse:9.41385	validation_1-rmse:8.28082
# [249]	validation_0-rmse:9.41318	validation_1-rmse:8.28055
# [250]	validation_0-rmse:9.41262	validation_1-rmse:8.28038
# [251]	validation_0-rmse:9.41206	validation_1-rmse:8.28030
# [252]	validation_0-rmse:9.41153	validation_1-rmse:8.28014
# [253]	validation_0-rmse:9.41094	validation_1-rmse:8.27995
# [254]	validation_0-rmse:9.41047	validation_1-rmse:8.27988
# [255]	validation_0-rmse:9.40996	validation_1-rmse:8.27971
# [256]	validation_0-rmse:9.40939	validation_1-rmse:8.27954
# [257]	validation_0-rmse:9.40887	validation_1-rmse:8.27939
# [258]	validation_0-rmse:9.40832	validation_1-rmse:8.27920
# [259]	validation_0-rmse:9.40778	validation_1-rmse:8.27904
# [260]	validation_0-rmse:9.40718	validation_1-rmse:8.27895
# [261]	validation_0-rmse:9.40673	validation_1-rmse:8.27886
# [262]	validation_0-rmse:9.40615	validation_1-rmse:8.27870
# [263]	validation_0-rmse:9.40569	validation_1-rmse:8.27850
# [264]	validation_0-rmse:9.40521	validation_1-rmse:8.27842
# [265]	validation_0-rmse:9.40471	validation_1-rmse:8.27828
# [266]	validation_0-rmse:9.40421	validation_1-rmse:8.27818
# [267]	validation_0-rmse:9.40357	validation_1-rmse:8.27798
# [268]	validation_0-rmse:9.40304	validation_1-rmse:8.27785
# [269]	validation_0-rmse:9.40256	validation_1-rmse:8.27774
# [270]	validation_0-rmse:9.40211	validation_1-rmse:8.27765
# [271]	validation_0-rmse:9.40154	validation_1-rmse:8.27753
# [272]	validation_0-rmse:9.40099	validation_1-rmse:8.27740
# [273]	validation_0-rmse:9.40044	validation_1-rmse:8.27723
# [274]	validation_0-rmse:9.39991	validation_1-rmse:8.27711
# [275]	validation_0-rmse:9.39935	validation_1-rmse:8.27695
# [276]	validation_0-rmse:9.39889	validation_1-rmse:8.27689
# [277]	validation_0-rmse:9.39825	validation_1-rmse:8.27654
# [278]	validation_0-rmse:9.39767	validation_1-rmse:8.27641
# [279]	validation_0-rmse:9.39701	validation_1-rmse:8.27614
# [280]	validation_0-rmse:9.39648	validation_1-rmse:8.27611
# [281]	validation_0-rmse:9.39603	validation_1-rmse:8.27598
# [282]	validation_0-rmse:9.39542	validation_1-rmse:8.27577
# [283]	validation_0-rmse:9.39493	validation_1-rmse:8.27565
# [284]	validation_0-rmse:9.39442	validation_1-rmse:8.27560
# [285]	validation_0-rmse:9.39380	validation_1-rmse:8.27541
# [286]	validation_0-rmse:9.39322	validation_1-rmse:8.27526
# [287]	validation_0-rmse:9.39264	validation_1-rmse:8.27511
# [288]	validation_0-rmse:9.39222	validation_1-rmse:8.27495
# [289]	validation_0-rmse:9.39174	validation_1-rmse:8.27485
# [290]	validation_0-rmse:9.39127	validation_1-rmse:8.27473
# [291]	validation_0-rmse:9.39079	validation_1-rmse:8.27460
# [292]	validation_0-rmse:9.39032	validation_1-rmse:8.27450
# [293]	validation_0-rmse:9.38978	validation_1-rmse:8.27425
# [294]	validation_0-rmse:9.38933	validation_1-rmse:8.27414
# [295]	validation_0-rmse:9.38882	validation_1-rmse:8.27403
# [296]	validation_0-rmse:9.38833	validation_1-rmse:8.27394
# [297]	validation_0-rmse:9.38775	validation_1-rmse:8.27383
# [298]	validation_0-rmse:9.38720	validation_1-rmse:8.27375
# [299]	validation_0-rmse:9.38666	validation_1-rmse:8.27357
# [300]	validation_0-rmse:9.38610	validation_1-rmse:8.27339
# [301]	validation_0-rmse:9.38565	validation_1-rmse:8.27334
# [302]	validation_0-rmse:9.38513	validation_1-rmse:8.27313
# [303]	validation_0-rmse:9.38468	validation_1-rmse:8.27304
# [304]	validation_0-rmse:9.38399	validation_1-rmse:8.27271
# [305]	validation_0-rmse:9.38357	validation_1-rmse:8.27261
# [306]	validation_0-rmse:9.38307	validation_1-rmse:8.27251
# [307]	validation_0-rmse:9.38264	validation_1-rmse:8.27239
# [308]	validation_0-rmse:9.38219	validation_1-rmse:8.27224
# [309]	validation_0-rmse:9.38170	validation_1-rmse:8.27222
# [310]	validation_0-rmse:9.38117	validation_1-rmse:8.27215
# [311]	validation_0-rmse:9.38068	validation_1-rmse:8.27202
# [312]	validation_0-rmse:9.38022	validation_1-rmse:8.27184
# [313]	validation_0-rmse:9.37979	validation_1-rmse:8.27172
# [314]	validation_0-rmse:9.37940	validation_1-rmse:8.27161
# [315]	validation_0-rmse:9.37894	validation_1-rmse:8.27153
# [316]	validation_0-rmse:9.37839	validation_1-rmse:8.27138
# [317]	validation_0-rmse:9.37788	validation_1-rmse:8.27135
# [318]	validation_0-rmse:9.37737	validation_1-rmse:8.27112
# [319]	validation_0-rmse:9.37684	validation_1-rmse:8.27098
# [320]	validation_0-rmse:9.37641	validation_1-rmse:8.27086
# [321]	validation_0-rmse:9.37598	validation_1-rmse:8.27076
# [322]	validation_0-rmse:9.37554	validation_1-rmse:8.27065
# [323]	validation_0-rmse:9.37506	validation_1-rmse:8.27058
# [324]	validation_0-rmse:9.37454	validation_1-rmse:8.27040
# [325]	validation_0-rmse:9.37410	validation_1-rmse:8.27038
# [326]	validation_0-rmse:9.37362	validation_1-rmse:8.27036
# [327]	validation_0-rmse:9.37319	validation_1-rmse:8.27024
# [328]	validation_0-rmse:9.37270	validation_1-rmse:8.27020
# [329]	validation_0-rmse:9.37224	validation_1-rmse:8.27013
# [330]	validation_0-rmse:9.37180	validation_1-rmse:8.27003
# [331]	validation_0-rmse:9.37138	validation_1-rmse:8.26995
# [332]	validation_0-rmse:9.37102	validation_1-rmse:8.26986
# [333]	validation_0-rmse:9.37067	validation_1-rmse:8.26981
# [334]	validation_0-rmse:9.37013	validation_1-rmse:8.26970
# [335]	validation_0-rmse:9.36973	validation_1-rmse:8.26965
# [336]	validation_0-rmse:9.36932	validation_1-rmse:8.26954
# [337]	validation_0-rmse:9.36883	validation_1-rmse:8.26936
# [338]	validation_0-rmse:9.36832	validation_1-rmse:8.26929
# [339]	validation_0-rmse:9.36787	validation_1-rmse:8.26929
# [340]	validation_0-rmse:9.36733	validation_1-rmse:8.26911
# [341]	validation_0-rmse:9.36684	validation_1-rmse:8.26905
# [342]	validation_0-rmse:9.36639	validation_1-rmse:8.26893
# [343]	validation_0-rmse:9.36599	validation_1-rmse:8.26892
# [344]	validation_0-rmse:9.36556	validation_1-rmse:8.26886
# [345]	validation_0-rmse:9.36512	validation_1-rmse:8.26877
# [346]	validation_0-rmse:9.36465	validation_1-rmse:8.26873
# [347]	validation_0-rmse:9.36419	validation_1-rmse:8.26867
# [348]	validation_0-rmse:9.36372	validation_1-rmse:8.26856
# [349]	validation_0-rmse:9.36321	validation_1-rmse:8.26847
# [350]	validation_0-rmse:9.36278	validation_1-rmse:8.26839
# [351]	validation_0-rmse:9.36230	validation_1-rmse:8.26821
# [352]	validation_0-rmse:9.36179	validation_1-rmse:8.26809
# [353]	validation_0-rmse:9.36117	validation_1-rmse:8.26785
# [354]	validation_0-rmse:9.36069	validation_1-rmse:8.26777
# [355]	validation_0-rmse:9.36031	validation_1-rmse:8.26772
# [356]	validation_0-rmse:9.35988	validation_1-rmse:8.26765
# [357]	validation_0-rmse:9.35943	validation_1-rmse:8.26754
# [358]	validation_0-rmse:9.35887	validation_1-rmse:8.26747
# [359]	validation_0-rmse:9.35839	validation_1-rmse:8.26736
# [360]	validation_0-rmse:9.35795	validation_1-rmse:8.26725
# [361]	validation_0-rmse:9.35758	validation_1-rmse:8.26720
# [362]	validation_0-rmse:9.35718	validation_1-rmse:8.26707
# [363]	validation_0-rmse:9.35671	validation_1-rmse:8.26697
# [364]	validation_0-rmse:9.35631	validation_1-rmse:8.26681
# [365]	validation_0-rmse:9.35578	validation_1-rmse:8.26653
# [366]	validation_0-rmse:9.35533	validation_1-rmse:8.26645
# [367]	validation_0-rmse:9.35495	validation_1-rmse:8.26638
# [368]	validation_0-rmse:9.35456	validation_1-rmse:8.26632
# [369]	validation_0-rmse:9.35408	validation_1-rmse:8.26617
# [370]	validation_0-rmse:9.35353	validation_1-rmse:8.26601
# [371]	validation_0-rmse:9.35304	validation_1-rmse:8.26591
# [372]	validation_0-rmse:9.35255	validation_1-rmse:8.26576
# [373]	validation_0-rmse:9.35214	validation_1-rmse:8.26563
# [374]	validation_0-rmse:9.35174	validation_1-rmse:8.26552
# [375]	validation_0-rmse:9.35127	validation_1-rmse:8.26542
# [376]	validation_0-rmse:9.35085	validation_1-rmse:8.26530
# [377]	validation_0-rmse:9.35037	validation_1-rmse:8.26526
# [378]	validation_0-rmse:9.34999	validation_1-rmse:8.26515
# [379]	validation_0-rmse:9.34960	validation_1-rmse:8.26509
# [380]	validation_0-rmse:9.34925	validation_1-rmse:8.26499
# [381]	validation_0-rmse:9.34877	validation_1-rmse:8.26491
# [382]	validation_0-rmse:9.34820	validation_1-rmse:8.26473
# [383]	validation_0-rmse:9.34758	validation_1-rmse:8.26455
# [384]	validation_0-rmse:9.34716	validation_1-rmse:8.26448
# [385]	validation_0-rmse:9.34662	validation_1-rmse:8.26429
# [386]	validation_0-rmse:9.34620	validation_1-rmse:8.26417
# [387]	validation_0-rmse:9.34576	validation_1-rmse:8.26407
# [388]	validation_0-rmse:9.34534	validation_1-rmse:8.26396
# [389]	validation_0-rmse:9.34479	validation_1-rmse:8.26376
# [390]	validation_0-rmse:9.34423	validation_1-rmse:8.26356
# [391]	validation_0-rmse:9.34378	validation_1-rmse:8.26350
# [392]	validation_0-rmse:9.34336	validation_1-rmse:8.26346
# [393]	validation_0-rmse:9.34290	validation_1-rmse:8.26340
# [394]	validation_0-rmse:9.34251	validation_1-rmse:8.26333
# [395]	validation_0-rmse:9.34214	validation_1-rmse:8.26327
# [396]	validation_0-rmse:9.34169	validation_1-rmse:8.26313
# [397]	validation_0-rmse:9.34129	validation_1-rmse:8.26305
# [398]	validation_0-rmse:9.34085	validation_1-rmse:8.26295
# [399]	validation_0-rmse:9.34049	validation_1-rmse:8.26289
# [400]	validation_0-rmse:9.34007	validation_1-rmse:8.26285
# [401]	validation_0-rmse:9.33961	validation_1-rmse:8.26270
# [402]	validation_0-rmse:9.33913	validation_1-rmse:8.26248
# [403]	validation_0-rmse:9.33870	validation_1-rmse:8.26241
# [404]	validation_0-rmse:9.33831	validation_1-rmse:8.26232
# [405]	validation_0-rmse:9.33791	validation_1-rmse:8.26216
# [406]	validation_0-rmse:9.33751	validation_1-rmse:8.26204
# [407]	validation_0-rmse:9.33706	validation_1-rmse:8.26182
# [408]	validation_0-rmse:9.33674	validation_1-rmse:8.26181
# [409]	validation_0-rmse:9.33622	validation_1-rmse:8.26163
# [410]	validation_0-rmse:9.33579	validation_1-rmse:8.26151
# [411]	validation_0-rmse:9.33544	validation_1-rmse:8.26148
# ...
# 859:	learn: 9.4504402	test: 9.4504402	test1: 8.2630825	best: 8.2630825 (859)	total: 25m 10s	remaining: 4m 5s
# 860:	learn: 9.4503553	test: 9.4503553	test1: 8.2630595	best: 8.2630595 (860)	total: 25m 12s	remaining: 4m 4s
# 861:	learn: 9.4502431	test: 9.4502431	test1: 8.2630121	best: 8.2630121 (861)	total: 25m 14s	remaining: 4m 2s
# 862:	learn: 9.4501741	test: 9.4501741	test1: 8.2629983	best: 8.2629983 (862)	total: 25m 15s	remaining: 4m
# 863:	learn: 9.4500408	test: 9.4500408	test1: 8.2629387	best: 8.2629387 (863)	total: 25m 17s	remaining: 3m 58s
# 864:	learn: 9.4499780	test: 9.4499780	test1: 8.2629160	best: 8.2629160 (864)	total: 25m 18s	remaining: 3m 56s
# 865:	learn: 9.4498613	test: 9.4498613	test1: 8.2629746	best: 8.2629160 (864)	total: 25m 19s	remaining: 3m 55s
# 866:	learn: 9.4497561	test: 9.4497561	test1: 8.2629547	best: 8.2629160 (864)	total: 25m 21s	remaining: 3m 53s
# 867:	learn: 9.4496759	test: 9.4496759	test1: 8.2629547	best: 8.2629160 (864)	total: 25m 22s	remaining: 3m 51s
# 868:	learn: 9.4495665	test: 9.4495665	test1: 8.2629513	best: 8.2629160 (864)	total: 25m 23s	remaining: 3m 49s
# 985:	learn: 9.4365784	test: 9.4365784	test1: 8.2598174	best: 8.2598122 (984)	total: 28m 46s	remaining: 24.5s
# 986:	learn: 9.4364539	test: 9.4364539	test1: 8.2597702	best: 8.2597702 (986)	total: 28m 48s	remaining: 22.8s
# 987:	learn: 9.4363078	test: 9.4363078	test1: 8.2597667	best: 8.2597667 (987)	total: 28m 49s	remaining: 21s
# 988:	learn: 9.4361565	test: 9.4361565	test1: 8.2597160	best: 8.2597160 (988)	total: 28m 51s	remaining: 19.3s
# 989:	learn: 9.4360827	test: 9.4360827	test1: 8.2597014	best: 8.2597014 (989)	total: 28m 52s	remaining: 17.5s
# 990:	learn: 9.4360076	test: 9.4360076	test1: 8.2596803	best: 8.2596803 (990)	total: 28m 54s	remaining: 15.7s
# 991:	learn: 9.4359159	test: 9.4359159	test1: 8.2596576	best: 8.2596576 (991)	total: 28m 56s	remaining: 14s
# 992:	learn: 9.4358303	test: 9.4358303	test1: 8.2596369	best: 8.2596369 (992)	total: 28m 57s	remaining: 12.3s
# 993:	learn: 9.4357134	test: 9.4357134	test1: 8.2596333	best: 8.2596333 (993)	total: 28m 59s	remaining: 10.5s
# 994:	learn: 9.4356181	test: 9.4356181	test1: 8.2595960	best: 8.2595960 (994)	total: 29m	remaining: 8.75s
# 995:	learn: 9.4355129	test: 9.4355129	test1: 8.2595336	best: 8.2595336 (995)	total: 29m 2s	remaining: 7s
# 996:	learn: 9.4353940	test: 9.4353940	test1: 8.2595374	best: 8.2595336 (995)	total: 29m 4s	remaining: 5.25s
# 997:	learn: 9.4353023	test: 9.4353023	test1: 8.2595504	best: 8.2595336 (995)	total: 29m 5s	remaining: 3.5s
# 998:	learn: 9.4351660	test: 9.4351660	test1: 8.2594776	best: 8.2594776 (998)	total: 29m 7s	remaining: 1.75s
# 999:	learn: 9.4350882	test: 9.4350882	test1: 8.2594702	best: 8.2594702 (999)	total: 29m 9s	remaining: 0us
#
# bestTest = 8.259470181
# bestIteration = 999
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 57
#      55 model_filename = os.path.join(model_save_path, f'doblez_{i+1}.txt')
#      56 lgb_reg.booster_.save_model(model_filename)
# ---> 57 xgb_reg.booster_.save_model(model_filename)
#      58 cat_reg.booster_.save_model(model_filename)
#      59 print(f"Models for fold {i+1} saved to {model_filename}")
#
# AttributeError: 'XGBRegressor' object has no attribute 'booster_'

# %%
oof_df = pd.DataFrame({'lgb':oof_lgb,'xgb':oof_xgb,'cat':oof_cat})

# %%
from sklearn.linear_model import LogisticRegression

log_r = LogisticRegression()
log_r.fit(oof_df, df_train['target'])
final_pre1 = log_r.predict(test_output_df)
# Save the final model to a file
final_model_filename = os.path.join(model_save_path, 'doblez-conjunto.txt')
log_r.booster_.save_model(final_model_filename)
print(f"Final model saved to {final_model_filename}")

# Now 'models' holds the trained models for each fold and 'scores' holds the validation scores
print(f"Average LGB MAE across all folds: {np.mean(score_lgb)}")
print(f"Average XGB MAE across all folds: {np.mean(score_xgb)}")
print(f"Average CAT MAE across all folds: {np.mean(score_cat)}")

if is_offline:
    # offline predictions
    df_valid_target = df_valid["target"]
    offline_score = mean_absolute_error(final_pre1, df_valid_target)
    print(f"Offline Score {np.round(offline_score, 4)}")
